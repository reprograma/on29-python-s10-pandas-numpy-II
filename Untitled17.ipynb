# %% [markdown]
# <a href="https://colab.research.google.com/github/chaves08r/on29-python-s10-pandas-numpy-II/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_.csv', sep=';')

# %%
df
# Out:
#             Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0     2022/02/06  2300 UTC                             1.0
# 1     2022/06/14  1700 UTC                             NaN
# 2     2021/07/20  0200 UTC                             NaN
# 3     2022/01/08  0900 UTC                             NaN
# 4     2021/03/13  2200 UTC                             0.0
# ...          ...       ...                             ...
# 7429  2020/06/27  0400 UTC                             NaN
# 7430  2021/03/21  1900 UTC                             NaN
# 7431  2021/11/29  0100 UTC                             NaN
# 7432  2021/02/24  1900 UTC                             0.0
# 7433  2021/08/27  2300 UTC                             0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                 898.3
# 1                                                   NaN
# 2                                                   NaN
# ...

# %%
df[df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'] > 30]
# Out:
#             Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 42    2022/03/22  1400 UTC                             0.0
# 89    2021/09/18  1500 UTC                             0.0
# 108   2020/09/30  2100 UTC                             0.0
# 117   2022/10/08  2100 UTC                             0.0
# 126   2021/04/26  1600 UTC                             0.0
# ...          ...       ...                             ...
# 7362  2020/08/27  1800 UTC                             NaN
# 7386  2022/05/14  1800 UTC                             0.0
# 7387  2020/02/14  1700 UTC                             0.0
# 7421  2020/09/15  1600 UTC                             0.0
# 7424  2022/11/22  1700 UTC                             0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 42                                               1008.9
# 89                                                958.6
# 108                                               910.2
# ...

# %%
df[(df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'] < 30) & (df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'] > 18)]['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)']
# Out:
# 0       19.6
# 4       26.6
# 5       29.8
# 6       25.7
# 7       28.2
#         ...
# 7418    18.2
# 7422    25.9
# 7423    21.6
# 7427    28.3
# 7432    25.9
# Name: TEMPERATURA DO AR - BULBO SECO. HORARIA (C), Length: 3533, dtype: float64

# %%
cond_1 = df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'] < 30
cond_2 = df['UF'] == 'CE'
cond = cond_1 & cond_2
df[cond]
# Out:
#             Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 404   2022/05/11  1100 UTC                             0.0
# 536   2021/05/11  1000 UTC                             NaN
# 541   2020/01/24  0200 UTC                             0.0
# 542   2020/01/02  0100 UTC                             0.0
# 605   2021/01/24  0600 UTC                             0.0
# 881   2022/11/11  0000 UTC                             0.0
# 900   2020/11/07  0000 UTC                             0.0
# 1108  2021/10/12  1200 UTC                             NaN
# 1426  2022/12/29  0900 UTC                             0.0
# 1438  2021/10/06  0000 UTC                             0.0
# 1559  2020/07/25  0500 UTC                             0.0
# 2595  2022/03/29  1600 UTC                             0.0
# 2648  2020/10/27  1300 UTC                             0.0
# 2730  2022/12/17  0700 UTC                             0.0
# 2809  2020/05/29  0300 UTC                             NaN
# ...

# %%
df[df['UF'].isin(['CE', 'PA'])]
# Out:
#             Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 10    2022/06/12  1000 UTC                             NaN
# 26    2021/06/23  1100 UTC                             NaN
# 36    2021/01/17  2200 UTC                             0.0
# 37    2022/04/15  0800 UTC                             0.0
# 58    2022/06/20  0000 UTC                             NaN
# ...          ...       ...                             ...
# 7349  2021/05/19  1200 UTC                             NaN
# 7354  2020/01/20  0100 UTC                             0.0
# 7379  2022/01/24  2000 UTC                             NaN
# 7404  2021/12/30  0700 UTC                             NaN
# 7405  2020/01/28  0900 UTC                             0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 10                                                  NaN
# 26                                                  NaN
# 36                                                999.0
# ...

# %%
df[df['Data'].str.contains('2022/')]['Data']
# Out:
# 0       2022/02/06
# 1       2022/06/14
# 3       2022/01/08
# 7       2022/10/04
# 9       2022/06/18
#            ...
# 7424    2022/11/22
# 7425    2022/09/10
# 7426    2022/05/01
# 7427    2022/10/02
# 7428    2022/03/30
# Name: Data, Length: 2407, dtype: object

# %%
df.loc[ 10:20, ["Data", "Hora UTC","TEMPERATURA DO AR - BULBO SECO. HORARIA (C)"]]
# Out:
#           Data  Hora UTC  TEMPERATURA DO AR - BULBO SECO. HORARIA (C)
# 10  2022/06/12  1000 UTC                                          NaN
# 11  2021/08/12  2100 UTC                                         23.5
# 12  2020/08/18  1400 UTC                                         26.7
# 13  2021/08/24  0900 UTC                                          NaN
# 14  2021/06/20  2100 UTC                                         22.6
# 15  2022/07/13  2200 UTC                                         11.4
# 16  2020/05/17  2300 UTC                                          NaN
# 17  2020/05/18  1100 UTC                                         27.3
# 18  2020/03/20  0900 UTC                                         22.4
# 19  2022/05/19  0400 UTC                                          7.4
# 20  2022/04/06  0400 UTC                                          NaN

# %%
df.groupby('Hora UTC')[["PRECIPITAO TOTAL. HORARIO (mm)","TEMPERATURA DO AR - BULBO SECO. HORARIA (C)"]].mean()
# Out:
#           PRECIPITAO TOTAL. HORARIO (mm)  \
# Hora UTC
# 0000 UTC                        0.307429
# 0100 UTC                        0.162921
# 0200 UTC                        0.550000
# 0300 UTC                        0.152326
# 0400 UTC                        0.138144
# 0500 UTC                        0.060109
# 0600 UTC                        0.439759
# 0700 UTC                        0.137647
# 0800 UTC                        0.196685
# 0900 UTC                        0.145665
# 1000 UTC                        0.064423
# 1100 UTC                        0.205155
# 1200 UTC                        0.151381
# 1300 UTC                        0.171707
# 1400 UTC                        0.153623
# 1500 UTC                        0.134247
# 1600 UTC                        0.176190
# 1700 UTC                        0.197044
# 1800 UTC                        0.068317
# 1900 UTC                        0.244828
# 2000 UTC                        0.119149
# ...

# %%
df.groupby(['Hora UTC'])[["TEMPERATURA DO AR - BULBO SECO. HORARIA (C)"]].count()
# Out:
#           TEMPERATURA DO AR - BULBO SECO. HORARIA (C)
# Hora UTC
# 0000 UTC                                          193
# 0100 UTC                                          188
# 0200 UTC                                          190
# 0300 UTC                                          189
# 0400 UTC                                          218
# 0500 UTC                                          199
# 0600 UTC                                          188
# 0700 UTC                                          190
# 0800 UTC                                          202
# 0900 UTC                                          192
# 1000 UTC                                          231
# 1100 UTC                                          214
# 1200 UTC                                          198
# 1300 UTC                                          231
# 1400 UTC                                          229
# 1500 UTC                                          239
# ...

# %%
df_CE = pd.read_csv('data_sample_CE.csv', sep=';' , encoding='latin-1', on_bad_lines='skip')

# %%
df_PA = pd.read_csv('data_sample_PA.csv', sep=';' , encoding='latin-1', on_bad_lines='skip')

# %%
df_CE_PA = pd.concat([df_CE, df_PA])

# %%
df_CE_PA
# Out:
#             Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0     2021/05/10  1600 UTC                             NaN
# 1     2022/01/06  0500 UTC                             NaN
# 2     2020/12/30  2000 UTC                             NaN
# 3     2022/10/15  0800 UTC                             NaN
# 4     2021/04/03  1600 UTC                             0.0
# ...          ...       ...                             ...
# 8149  2022/09/13  0200 UTC                             NaN
# 8150  2022/09/30  1600 UTC                             0.0
# 8151  2020/03/09  2300 UTC                             0.4
# 8152  2021/02/10  1900 UTC                             0.0
# 8153  2020/12/23  0400 UTC                             NaN
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...
