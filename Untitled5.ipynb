# %% [markdown]
# <a href="https://colab.research.google.com/github/PamReprograma/on29-python-s10-pandas-numpy-II/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('megasena.csv', sep=',' )

# %%
df
# Out:
#       Concurso Data Sorteio  1ª Dezena  2ª Dezena  3ª Dezena  4ª Dezena  \
# 0          1.0   11/03/1996        4.0        5.0       30.0       33.0
# 1          2.0   18/03/1996        9.0       37.0       39.0       41.0
# 2          3.0   25/03/1996       10.0       11.0       29.0       30.0
# 3          NaN          NaN        NaN        NaN        NaN        NaN
# 4          4.0   01/04/1996        1.0        5.0        6.0       27.0
# ...        ...          ...        ...        ...        ...        ...
# 2027    1849.0   20/08/2016        3.0        5.0       11.0       27.0
# 2028    1850.0   24/08/2016       23.0       24.0       32.0       38.0
# 2029    1851.0   27/08/2016        8.0       18.0       21.0       22.0
# 2030    1852.0   31/08/2016       13.0       17.0       29.0       45.0
# 2031    1853.0   03/09/2016        1.0        2.0       34.0       39.0
#
#       5ª Dezena  6ª Dezena Arrecadacao_Total  Ganhadores_Sena  ...   UF  \
# ...

# %%
df['Ganhadores_Sena'].sum()
# Out:
# 627.0

# %%
df.describe()
# Out:
#           Concurso    1ª Dezena    2ª Dezena    3ª Dezena    4ª Dezena  \
# count  1853.000000  1853.000000  1853.000000  1853.000000  1853.000000
# mean    927.000000     8.584997    17.176471    26.264436    35.130059
# std     535.059343     7.051640     9.151511    10.004654     9.867526
# min       1.000000     1.000000     2.000000     3.000000     8.000000
# 25%     464.000000     3.000000    10.000000    19.000000    28.000000
# 50%     927.000000     7.000000    16.000000    26.000000    35.000000
# 75%    1390.000000    12.000000    23.000000    33.000000    43.000000
# max    1853.000000    46.000000    48.000000    54.000000    58.000000
#
#          5ª Dezena    6ª Dezena  Ganhadores_Sena  Ganhadores_Quina  \
# count  1853.000000  1853.000000      1853.000000       1853.000000
# mean     43.694010    52.393956         0.338370        112.593092
# std       9.014492     6.708382         0.781413        149.845437
# ...

# %%
# min das colunas de sorteio = 1  e max = 60  , tamanho da amostra 60.

# %%
df_menor = df.dropna(subset=['1ª Dezena',	'2ª Dezena'	,'3ª Dezena'	,'4ª Dezena'	,'5ª Dezena',	'6ª Dezena'])

# %%
df_menor
# Out:
#       Concurso Data Sorteio  1ª Dezena  2ª Dezena  3ª Dezena  4ª Dezena  \
# 0          1.0   11/03/1996        4.0        5.0       30.0       33.0
# 1          2.0   18/03/1996        9.0       37.0       39.0       41.0
# 2          3.0   25/03/1996       10.0       11.0       29.0       30.0
# 4          4.0   01/04/1996        1.0        5.0        6.0       27.0
# 5          5.0   08/04/1996        1.0        2.0        6.0       16.0
# ...        ...          ...        ...        ...        ...        ...
# 2027    1849.0   20/08/2016        3.0        5.0       11.0       27.0
# 2028    1850.0   24/08/2016       23.0       24.0       32.0       38.0
# 2029    1851.0   27/08/2016        8.0       18.0       21.0       22.0
# 2030    1852.0   31/08/2016       13.0       17.0       29.0       45.0
# 2031    1853.0   03/09/2016        1.0        2.0       34.0       39.0
#
#       5ª Dezena  6ª Dezena Arrecadacao_Total  Ganhadores_Sena  ...   UF  \
# ...

# %%
import math

# %%
# Numero de Classes: (k)

# %%
k = math.sqrt(60)

# %%
k= math.ceil(7.745966692414834)

# %%
k
# Out:
# 8

# %%
# amplitude: (a) A = Maior valor observado - menor valor observado  = 60 -1 = 59

# %%
# Amplitude da classe c = a /k-1  =

# %%
c = 59/(8-1)

# %%
c
# Out:
# 8.428571428571429

# %%
# limite inferior = menor valor observado - (c/2) =

# %%
LI = 1/(c/2)

# %%
LI
# Out:
# 0.23728813559322035

# %%
# limite supeerior = LI +  c

# %%
LS = LI + c

# %%
LS
# Out:
# 8.665859564164649

# %%
import matplotlib.pyplot as plt

# %%
sorteados = pd.concat([df_menor['1ª Dezena'], df_menor['2ª Dezena'], df_menor['3ª Dezena'],
                           df_menor['4ª Dezena'], df_menor['5ª Dezena'], df_menor['6ª Dezena']])

# %%
plt.hist(sorteados,bins = int(c), range = (float(1), float(60)), edgecolor = 'black')
plt.title('Histograma dos numeros sorteados')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.grid(True)
